# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import dtype, ndarray
from zimg import ZImg


def normalize_image(image: ndarray, target_dtype: dtype) -> ndarray:
    assert target_dtype.kind == "u"
    image_min, image_max = image.min(), image.max()
    target_max = np.iinfo(target_dtype).max
    return ((image - image_min) / (image_max - image_min) * target_max).astype(
        target_dtype
    )


data_path = r'D:\WorkData\czi\luo_0008.nim'
zimg_obj = ZImg(data_path)
zimg_data = zimg_obj.data[0][0, 0]
zimg_data = normalize_image(zimg_data, target_dtype=np.dtype(np.uint8))

plt.imshow(zimg_data, cmap='gray')
